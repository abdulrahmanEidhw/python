# %%
# importing required libraies
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #drawing library
from sklearn import datasets
dataset=pd.read_csv(r'C:\Users\2\Desktop\theProject\Wholesale customers data.csv',
                        delimiter=',',
                        header=0)
dataset.head(9)
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185
# 5        2       3   9413  8259     5126     666              1795        1451
# 6        2       3  12126  3199     6975     480              3140         545
# 7        2       3   7579  4956     9426    1669              3321        2566
# 8        1       3   5963  3648     6192     425              1716         750

# %%
## 8 columns and 100 attribute
print(dataset.shape)
# Out:
# (99, 8)

# %%
## count,mean,standard div,min, quartile for each attribute
print(dataset.describe())
# Out:
#          Channel  Region         Fresh          Milk       Grocery  \
# count  99.000000    99.0     99.000000     99.000000     99.000000
# mean    1.525253     3.0  12990.797980   8389.151515  11244.565657
# std     0.501903     0.0  11453.105796  11589.952711  13518.974241
# min     1.000000     3.0      3.000000    112.000000      3.000000
# 25%     1.000000     3.0   5074.000000   2068.500000   3452.500000
# 50%     2.000000     3.0   9898.000000   4786.000000   7417.000000
# 75%     2.000000     3.0  18995.500000   9598.000000  12299.000000
# max     2.000000     3.0  56159.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count     99.000000         99.000000     99.000000
# mean    2787.060606       4501.141414   2024.838384
# std     4252.445457       6528.518771   2844.047481
# min       33.000000          3.000000     27.000000
# 25%      536.500000        618.500000    466.500000
# 50%     1256.000000       2575.000000   1130.000000
# 75%     3365.000000       5089.500000   2255.000000
# max    35009.000000      40827.000000  16523.000000

# %%
for ojha, feature in enumerate(list(dataset.columns)[:-1]):
    fg = sns.FacetGrid(dataset, hue='Region', height=5)
    fg.map(sns.distplot, feature).add_legend()
    plt.show()
# Out:
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x='Region', y='Fresh', data=dataset)
plt.show()
sns.boxplot(x='Region', y='Channel', data=dataset)
plt.show()
sns.boxplot(x='Region', y='Milk', data=dataset)
plt.show()
sns.boxplot(x='Region', y='Grocery', data=dataset)
plt.show()
sns.boxplot(x='Region', y='Frozen', data=dataset)
plt.show()
sns.boxplot(x='Region', y='Frozen', data=dataset)
plt.show()

# %%
sns.boxplot(x='Region', y='Detergents_Paper', data=dataset)
plt.show()

# %%
 sns.boxplot(x='Region', y='Delicassen', data=dataset)
plt.show()

# %%
sns.violinplot(x='Region', y='Milk', data=dataset)
plt.show()

# %%
data=dataset.plot(kind='scatter',x='Grocery',y='Milk',c= 'g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set_style("whitegrid")
sns.FacetGrid(dataset, hue="Milk",height=10) \
    .map(plt.scatter, "Milk","Grocery") \
    .add_legend();
plt.show();

# %%
sns.set_style("whitegrid");
sns.pairplot(dataset, hue = 'Channel', diag_kind = 'kde',
              plot_kws = {'alpha': 0.3, 's': 30, 'edgecolor': 'k'}, size =2)
plt.show()
# Out:
# C:\Users\2\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
dataset.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
print(dataset["Channel"].value_counts())
print(dataset["Region"].value_counts())
print(dataset["Fresh"].value_counts())
print(dataset["Milk"].value_counts())
print(dataset["Grocery"].value_counts())
print(dataset["Frozen"].value_counts())
print(dataset["Detergents_Paper"].value_counts())
print(dataset["Delicassen"].value_counts())
# Out:
# 2    52
# 1    47
# Name: Channel, dtype: int64
# 3    99
# Name: Region, dtype: int64
# 18815    1
# 8352     1
# 9396     1
# 35942    1
# 16705    1
#         ..
# 219      1
# 7005     1
# 12126    1
# 56159    1
# 21632    1
# Name: Fresh, Length: 99, dtype: int64
# 3199     1
# 3065     1
# 5025     1
# 5410     1
# 803      1
#         ..
# 9540     1
# 11095    1
# 3259     1
# 1114     1
# 73498    1
# Name: Milk, Length: 99, dtype: int64
# 4221     1
# 1947     1
# 7198     1
# 15775    1
# 4814     1
#         ..
# 1293     1
# 2262     1
# 32034    1
# 12121    1
# 7326     1
# Name: Grocery, Length: 99, dtype: int64
# 425     2
# 895     1
# 287     1
# 33      1
# 5154    1
#        ..
# 669     1
# 38      1
# 1178    1
# 1200    1
# 1920    1
# Name: Frozen, Length: 98, dtype: int64
# 4095     1
# 40827    1
# 3837     1
# 4003     1
# 1538     1
#         ..
# 18906    1
# 54       1
# 529      1
# 3293     1
# 7425     1
# Name: Detergents_Paper, Length: 99, dtype: int64
# 436      2
# 46       2
# 65       1
# 167      1
# 14472    1
#         ..
# 4334     1
# 1278     1
# 1117     1
# 3178     1
# 2944     1
# Name: Delicassen, Length: 97, dtype: int64

# %%
PCA_df = pd.read_csv(dataet, names=['Channel',

     'Region',

     'Fresh',

     'Milk','Grocery','Frozen','Detergents_Paper','Delicassen'])

# %% [markdown]
# ## -----------------------------------------------
# ## errors(lab6)
# ## -----------------------------------------------

# %%
features = ['Channel',

     'Region',

     'Fresh',

     'Milk','Grocery','Frozen','Detergents_Paper','Delicassen']

# Separating out the features
# :, gives u from the start to all colmns
x = PCA_df.loc[:, features].values

# Separating out the target

y = PCA_df.loc[:,['Delicassen']].values

# Standardizing the features

#x = StandardScaler().fit_transform(x)

#mini max feature
#x =  MinMaxScaler().fit_transform(x)

print (x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-6c5a1941be3d> in <module>
#      27 X_np = X_replace.values
#      28 # set the object type as float
# ---> 29 X_fa = X_np.astype(float)
#      30 #mini max feature
#      31 #x =  MinMaxScaler().fit_transform(x)
#
# ValueError: could not convert string to float: 'Channel'

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-cac9708d9d50> in <module>
# ----> 1 principalComponents = pca.fit_transform(data['Milk',[]].values)
#
# TypeError: 'AxesSubplot' object is not subscriptable
