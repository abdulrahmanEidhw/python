# %%
# importing required libraies
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #drawing library
from sklearn import datasets
dataset=pd.read_csv(r'C:\Users\2\Desktop\New folder\Wholesale customers data.csv',
                        delimiter=',',
                        header=0)
dataset.head(9)
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185
# 5        2       3   9413  8259     5126     666              1795        1451
# 6        2       3  12126  3199     6975     480              3140         545
# 7        2       3   7579  4956     9426    1669              3321        2566
# 8        1       3   5963  3648     6192     425              1716         750

# %%
## 8 columns and 440 attribute
print(dataset.shape)
# Out:
# (440, 8)

# %%
## count,mean,standard div,min, quartile
print(dataset.describe())
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
for ojha, feature in enumerate(list(dataset.columns)[:-1]):
    fg = sns.FacetGrid(dataset, hue='Region', height=5)
    fg.map(sns.distplot, feature).add_legend()
    plt.show()
# Out:
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\2\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.boxplot(x='Region', y='Milk', data=dataset)
plt.show()

# %%
sns.violinplot(x='Region', y='Milk', data=dataset)
plt.show()

# %%
data=dataset.plot(kind='scatter',x='Milk',y='Region',c= 'g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set_style("whitegrid")
sns.FacetGrid(dataset, hue="Region",height=10) \
    .map(plt.scatter, "Milk","Delicassen") \
    .add_legend();
plt.show();

# %%
sns.set_style("whitegrid");
sns.pairplot(dataset, hue = 'Channel', diag_kind = 'kde',
              plot_kws = {'alpha': 0.3, 's': 30, 'edgecolor': 'k'}, size =2)
plt.show()
# Out:
# C:\Users\2\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
dataset.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
print(dataset["Channel"].value_counts())
print(dataset["Region"].value_counts())
print(dataset["Fresh"].value_counts())
print(dataset["Milk"].value_counts())
print(dataset["Grocery"].value_counts())
print(dataset["Frozen"].value_counts())
print(dataset["Detergents_Paper"].value_counts())
print(dataset["Delicassen"].value_counts())
# Out:
# 1    298
# 2    142
# Name: Channel, dtype: int64
# 3    316
# 1     77
# 2     47
# Name: Region, dtype: int64
# 9670     2
# 3        2
# 8040     2
# 514      2
# 18044    2
#         ..
# 8885     1
# 694      1
# 7864     1
# 1725     1
# 4098     1
# Name: Fresh, Length: 433, dtype: int64
# 1897     2
# 5139     2
# 659      2
# 829      2
# 944      2
#         ..
# 7845     1
# 3748     1
# 13316    1
# 28326    1
# 20484    1
# Name: Milk, Length: 421, dtype: int64
# 1664    2
# 2405    2
# 1493    2
# 1563    2
# 3600    2
#        ..
# 582     1
# 2469    1
# 3779    1
# 1733    1
# 3       1
# Name: Grocery, Length: 430, dtype: int64
# 744     2
# 779     2
# 1619    2
# 364     2
# 848     2
#        ..
# 660     1
# 661     1
# 662     1
# 666     1
# 1026    1
# Name: Frozen, Length: 426, dtype: int64
# 227      2
# 311      2
# 118      2
# 811      2
# 788      2
#         ..
# 610      1
# 2662     1
# 24171    1
# 9836     1
# 5121     1
# ...

# %%
# if there are null value
modData = dataset.append({'Channel' : 0 , 'Region' : 3.6, 'Fresh': 0,

            'Milk': 0.2, 'Grocery': 5,'Frozen': 3,'Detergents_Paper':0,'Delicassen':0 } , ignore_index=True)

# %%
print('\n column with zero values')
print((modData[['Channel','Region','Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']]==0).sum())
# Out:
#  column with zero values
# Channel             1
# Region              0
# Fresh               1
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    1
# Delicassen          1
# dtype: int64

# %%
#replace all zeros with null value
modData[['Channel',

     'Region',

     'Fresh',

     'Milk','Grocery','Frozen','Detergents_Paper','Delicassen']] = modData[['Channel',

     'Region',

     'Fresh',

     'Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].replace(0, np.NaN)


print('Columns with missing values')

print(modData.isnull().sum())
# Out:
# Columns with missing values
# Channel             1
# Region              0
# Fresh               1
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    1
# Delicassen          1
# dtype: int64

# %%
modData.fillna(modData.mean(), inplace=True)
print(modData.isnull().sum())
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
modData.fillna(modData.median(), inplace=True)
print(modData.isnull().sum())
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
url = r'C:\Users\2\Desktop\New folder\Wholesale customers data.csv'

# load dataset into Pandas DataFrame

# %%
PCA_df = pd.read_csv(url, names=['Channel',

     'Region',

     'Fresh',

     'Milk','Grocery','Frozen','Detergents_Paper','Delicassen'])

# %%
features = ['Channel',

     'Region',

     'Fresh',

     'Milk','Grocery','Frozen','Detergents_Paper','Delicassen']

# Separating out the features
# :, gives u from the start to all colmns
x = PCA_df.loc[:, features].values

# Separating out the target

y = PCA_df.loc[:,['Milk']].values

# Standardizing the features

#x = StandardScaler().fit_transform(x)

#mini max feature
#x =  MinMaxScaler().fit_transform(x)

print (x)
# Out:
# [['Channel' 'Region' 'Fresh' ... 'Frozen' 'Detergents_Paper' 'Delicassen']
#  ['2' '3' '12669' ... '214' '2674' '1338']
#  ['2' '3' '7057' ... '1762' '3293' '1776']
#  ...
#  ['2' '3' '14531' ... '437' '14841' '1867']
#  ['1' '3' '10290' ... '1038' '168' '2125']
#  ['1' '3' '2787' ... '65' '477' '52']]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %% [markdown]
# ## -----------------------------------------------
#
#
# ## -----------------------------------------------

# %%
principalComponents = pca.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-96fb96c90c85> in <module>
# ----> 1 principalComponents = pca.fit_transform(y)
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, V = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     395                             'TruncatedSVD for a possible alternative.')
#     396
# --> 397         X = self._validate_data(X, dtype=[np.float64, np.float32],
#     398                                 ensure_2d=True, copy=self.copy)
#     399
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
principalDf = pd.DataFrame(data = principalComponents

       , columns = ['principal component 1', 'principal component 2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-c302c1a7f24e> in <module>
# ----> 1 principalDf = pd.DataFrame(data = principalComponents
#       2
#       3        , columns = ['principal component 1', 'principal component 2'])
#
# NameError: name 'principalComponents' is not defined
